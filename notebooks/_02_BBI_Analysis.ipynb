# %%
import datetime
import matplotlib.pyplot as plt
from pathlib import Path
import pylabfront.loader
import pylabfront.respiration

# %%
base_folder = Path('..') / 'sample_data'
labfront_loader = pylabfront.loader.LabfrontLoader(base_folder)

# %%
labfront_loader.load_garmin_device_bbi("sample-participant-01")
# Out:
#              timezone  unixTimestampInMs                 isoDate  \
# 0       Europe/Zurich      1680174000060 2023-03-30 13:00:00.060
# 1       Europe/Zurich      1680174000646 2023-03-30 13:00:00.646
# 2       Europe/Zurich      1680174001207 2023-03-30 13:00:01.207
# 3       Europe/Zurich      1680174001754 2023-03-30 13:00:01.754
# 4       Europe/Zurich      1680174002116 2023-03-30 13:00:02.116
# ...               ...                ...                     ...
# 249995  Europe/Zurich      1680402106120 2023-04-02 04:21:46.120
# 249996  Europe/Zurich      1680402107104 2023-04-02 04:21:47.104
# 249997  Europe/Zurich      1680402108080 2023-04-02 04:21:48.080
# 249998  Europe/Zurich      1680402110896 2023-04-02 04:21:50.896
# 249999  Europe/Zurich      1680402111837 2023-04-02 04:21:51.837
#
#               deviceType   bbi
# 0       garmin_Fenix6Pro   585
# 1       garmin_Fenix6Pro   561
# 2       garmin_Fenix6Pro   547
# 3       garmin_Fenix6Pro   531
# 4       garmin_Fenix6Pro   518
# ...                  ...   ...
# 249995  garmin_Fenix6Pro   984
# 249996  garmin_Fenix6Pro   962
# 249997  garmin_Fenix6Pro  1017
# 249998  garmin_Fenix6Pro   941
# 249999  garmin_Fenix6Pro   921
#
# [250000 rows x 5 columns]
